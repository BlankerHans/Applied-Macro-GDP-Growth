# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("dark_background")
import numpy as np

# %%
data = pd.read_csv("~/Schreibtisch/Studium/Master/Applied Macro/oecd_gdp.csv", index_col=5)

# %%
df = pd.DataFrame(data)
df
# Out:
#      LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY        Value Flag Codes
# TIME
# 1960      AUS       GDP     TOT  USD_CAP         A  2412.627589        NaN
# 1961      AUS       GDP     TOT  USD_CAP         A  2383.188902        NaN
# 1962      AUS       GDP     TOT  USD_CAP         A  2577.332834        NaN
# 1963      AUS       GDP     TOT  USD_CAP         A  2752.620592        NaN
# 1964      AUS       GDP     TOT  USD_CAP         A  2902.590472        NaN
# ...       ...       ...     ...      ...       ...          ...        ...
# 2016      SEN       GDP     TOT  USD_CAP         A  3116.185752        NaN
# 2017      SEN       GDP     TOT  USD_CAP         A  3238.212275        NaN
# 2018      SEN       GDP     TOT  USD_CAP         A  3416.171427        NaN
# 2019      SEN       GDP     TOT  USD_CAP         A  3530.096494        NaN
# 2020      SEN       GDP     TOT  USD_CAP         A  3513.149951        NaN
#
# [2586 rows x 7 columns]

# %%
df["TIME"].min()
# Out:
# 1960

# %%
df["TIME"].max()
# Out:
# 2022

# %%
df["LOCATION"].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'CHL', 'CHN', 'COL', 'EST', 'IND', 'IDN',
#        'ISR', 'RUS', 'SVN', 'ZAF', 'DEW', 'OECD', 'OECDE', 'LVA', 'BRA',
#        'LTU', 'SAU', 'EA19', 'ARG', 'CRI', 'BGR', 'HRV', 'CYP', 'MLT',
#        'ROU', 'MKD', 'ZMB', 'HKG', 'MDG', 'MAR', 'SGP', 'EU27_2020',
#        'ALB', 'SRB', 'GEO', 'CMR', 'SEN'], dtype=object)

# %%
np.array(df.index).max()
# Out:
# 2022

# %%
fig, ax = plt.subplots()

# Iteration über eindeutige Länder in der Spalte "LOCATION"
for country, group in df.groupby('LOCATION'):
    if country in ["DEU", "CHN", "JPN", "USA", "CHE"]:
        group.plot(y='Value', ax=ax, label=country, grid=False)
plt.title("Economic Growth")
plt.legend(loc="best")
plt.ylabel("GDP per capita in $")
plt.xlabel("Year")
plt.tight_layout()
ax.yaxis.set(ticks=np.arange(0, 110000, 10000))
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])
# Out:
# [Text(0, 0, '0'),
#  Text(0, 10000, '10,000'),
#  Text(0, 20000, '20,000'),
#  Text(0, 30000, '30,000'),
#  Text(0, 40000, '40,000'),
#  Text(0, 50000, '50,000'),
#  Text(0, 60000, '60,000'),
#  Text(0, 70000, '70,000'),
#  Text(0, 80000, '80,000'),
#  Text(0, 90000, '90,000'),
#  Text(0, 100000, '100,000')]

# %%
alpha = 1/4

# %%
k = np.arange(0, 100, 0.1)

# %%
output_per_capita =  k**alpha

# %%
capital_acc = 0.4*output_per_capita

# %%
fig, ax = plt.subplots(1, figsize=(16, 8))
ax.plot(k, output_per_capita)
ax.plot(k, capital_acc)
ax.plot(np.arange(0, 5, 0.1)*30, np.arange(0, 5, 0.1))
plt.xticks([])
plt.yticks([])
plt.xlabel("k = K/L")
plt.show()
